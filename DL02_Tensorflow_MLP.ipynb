# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaehwi-So/DeepLearning_Study/blob/main/DL02_Tensorflow_MLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_iris

# 데이터 로드
iris = load_iris()
X, y = iris.data, iris.target

# 데이터 전처리
scaler = StandardScaler()  # 특성 표준화를 위한 StandardScaler 객체 생성
X_scaled = scaler.fit_transform(X)  # 데이터를 표준화된 형태로 변환

# 훈련 세트와 테스트 세트로 분할
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# 모델 정의

# Sequential 모델 생성: 층을 순차적으로 쌓아나가는 신경망 모델
model = tf.keras.Sequential([
    # 입력층 및 첫 번째 은닉층: 64개의 뉴런과 ReLU 활성화 함수 사용
    tf.keras.layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    # 두 번째 은닉층: 64개의 뉴런과 ReLU 활성화 함수 사용
    tf.keras.layers.Dense(64, activation='relu'),
    # 출력층: 3개의 뉴런(클래스 수)과 softmax 활성화 함수 사용
    tf.keras.layers.Dense(3, activation='softmax')
])

# 모델 컴파일: Adam 옵티마이저, 손실 함수는 sparse_categorical_crossentropy(다중 클래스 분류 -> CCE를 사용해야 한다고 하였다)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# 모델 학습: 50 에포크 동안, 배치 크기는 32로 설정, 테스트 세트를 검증 데이터로 사용하여 학습 진행
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))

# 모델 평가
test_loss, test_acc = model.evaluate(X_test, y_test)  # 테스트 데이터를 사용하여 모델 평가
print("Test Accuracy:", test_acc)  # 테스트 정확도 출력
# Out:
# Epoch 1/50
# 4/4 [==============================] - 1s 121ms/step - loss: 1.1187 - accuracy: 0.2333 - val_loss: 1.0305 - val_accuracy: 0.5333
# Epoch 2/50
# 4/4 [==============================] - 0s 17ms/step - loss: 0.9780 - accuracy: 0.7000 - val_loss: 0.9030 - val_accuracy: 0.8667
# Epoch 3/50
# 4/4 [==============================] - 0s 17ms/step - loss: 0.8742 - accuracy: 0.7917 - val_loss: 0.7948 - val_accuracy: 0.8667
# Epoch 4/50
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7843 - accuracy: 0.7917 - val_loss: 0.7060 - val_accuracy: 0.8667
# Epoch 5/50
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7094 - accuracy: 0.8000 - val_loss: 0.6281 - val_accuracy: 0.8667
# Epoch 6/50
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6437 - accuracy: 0.8083 - val_loss: 0.5621 - val_accuracy: 0.9000
# Epoch 7/50
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5887 - accuracy: 0.8167 - val_loss: 0.5056 - val_accuracy: 0.9000
# Epoch 8/50
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5403 - accuracy: 0.8167 - val_loss: 0.4580 - val_accuracy: 0.9000
# Epoch 9/50
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4987 - accuracy: 0.8167 - val_loss: 0.4170 - val_accuracy: 0.9000
# Epoch 10/50
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4620 - accuracy: 0.8250 - val_loss: 0.3821 - val_accuracy: 0.9000
# Epoch 11/50
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4310 - accuracy: 0.8333 - val_loss: 0.3522 - val_accuracy: 0.9000
# Epoch 12/50
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4046 - accuracy: 0.8417 - val_loss: 0.3266 - val_accuracy: 0.9000
# Epoch 13/50
# 4/4 [==============================] - 0s 23ms/step - loss: 0.3817 - accuracy: 0.8417 - val_loss: 0.3049 - val_accuracy: 0.9000
# Epoch 14/50
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3609 - accuracy: 0.8500 - val_loss: 0.2857 - val_accuracy: 0.9000
# Epoch 15/50
# 4/4 [==============================] - 0s 22ms/step - loss: 0.3438 - accuracy: 0.8500 - val_loss: 0.2694 - val_accuracy: 0.9000
# Epoch 16/50
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3283 - accuracy: 0.8583 - val_loss: 0.2549 - val_accuracy: 0.9000
# Epoch 17/50
# 4/4 [==============================] - 0s 24ms/step - loss: 0.3140 - accuracy: 0.8583 - val_loss: 0.2426 - val_accuracy: 0.9333
# Epoch 18/50
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3013 - accuracy: 0.8667 - val_loss: 0.2318 - val_accuracy: 0.9333
# Epoch 19/50
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2899 - accuracy: 0.8750 - val_loss: 0.2207 - val_accuracy: 0.9333
# Epoch 20/50
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2783 - accuracy: 0.8917 - val_loss: 0.2105 - val_accuracy: 0.9333
# Epoch 21/50
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2679 - accuracy: 0.8917 - val_loss: 0.2008 - val_accuracy: 0.9333
# Epoch 22/50
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2578 - accuracy: 0.9000 - val_loss: 0.1914 - val_accuracy: 0.9333
# Epoch 23/50
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2478 - accuracy: 0.9083 - val_loss: 0.1830 - val_accuracy: 0.9333
# Epoch 24/50
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2375 - accuracy: 0.9250 - val_loss: 0.1749 - val_accuracy: 0.9333
# Epoch 25/50
# 4/4 [==============================] - 0s 22ms/step - loss: 0.2286 - accuracy: 0.9417 - val_loss: 0.1678 - val_accuracy: 0.9333
# Epoch 26/50
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2192 - accuracy: 0.9417 - val_loss: 0.1614 - val_accuracy: 0.9333
# Epoch 27/50
# 4/4 [==============================] - 0s 22ms/step - loss: 0.2122 - accuracy: 0.9417 - val_loss: 0.1545 - val_accuracy: 0.9333
# Epoch 28/50
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2033 - accuracy: 0.9500 - val_loss: 0.1500 - val_accuracy: 0.9333
# Epoch 29/50
# 4/4 [==============================] - 0s 23ms/step - loss: 0.1949 - accuracy: 0.9500 - val_loss: 0.1436 - val_accuracy: 0.9333
# Epoch 30/50
# 4/4 [==============================] - 0s 23ms/step - loss: 0.1892 - accuracy: 0.9583 - val_loss: 0.1359 - val_accuracy: 0.9667
# Epoch 31/50
# 4/4 [==============================] - 0s 23ms/step - loss: 0.1823 - accuracy: 0.9583 - val_loss: 0.1326 - val_accuracy: 0.9333
# Epoch 32/50
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1742 - accuracy: 0.9583 - val_loss: 0.1252 - val_accuracy: 1.0000
# Epoch 33/50
# 4/4 [==============================] - 0s 21ms/step - loss: 0.1670 - accuracy: 0.9583 - val_loss: 0.1206 - val_accuracy: 1.0000
# Epoch 34/50
# 4/4 [==============================] - 0s 22ms/step - loss: 0.1607 - accuracy: 0.9583 - val_loss: 0.1167 - val_accuracy: 1.0000
# Epoch 35/50
# 4/4 [==============================] - 0s 22ms/step - loss: 0.1559 - accuracy: 0.9583 - val_loss: 0.1137 - val_accuracy: 1.0000
# Epoch 36/50
# 4/4 [==============================] - 0s 22ms/step - loss: 0.1497 - accuracy: 0.9583 - val_loss: 0.1083 - val_accuracy: 1.0000
# Epoch 37/50
# 4/4 [==============================] - 0s 23ms/step - loss: 0.1439 - accuracy: 0.9583 - val_loss: 0.1042 - val_accuracy: 1.0000
# Epoch 38/50
# 4/4 [==============================] - 0s 24ms/step - loss: 0.1390 - accuracy: 0.9583 - val_loss: 0.0985 - val_accuracy: 1.0000
# Epoch 39/50
# 4/4 [==============================] - 0s 20ms/step - loss: 0.1343 - accuracy: 0.9583 - val_loss: 0.0954 - val_accuracy: 1.0000
# Epoch 40/50
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1288 - accuracy: 0.9583 - val_loss: 0.0931 - val_accuracy: 1.0000
# Epoch 41/50
# 4/4 [==============================] - 0s 25ms/step - loss: 0.1243 - accuracy: 0.9667 - val_loss: 0.0896 - val_accuracy: 1.0000
# Epoch 42/50
# 4/4 [==============================] - 0s 21ms/step - loss: 0.1212 - accuracy: 0.9667 - val_loss: 0.0869 - val_accuracy: 1.0000
# Epoch 43/50
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1175 - accuracy: 0.9667 - val_loss: 0.0825 - val_accuracy: 1.0000
# Epoch 44/50
# 4/4 [==============================] - 0s 22ms/step - loss: 0.1125 - accuracy: 0.9667 - val_loss: 0.0801 - val_accuracy: 1.0000
# Epoch 45/50
# 4/4 [==============================] - 0s 24ms/step - loss: 0.1092 - accuracy: 0.9667 - val_loss: 0.0771 - val_accuracy: 1.0000
# Epoch 46/50
# 4/4 [==============================] - 0s 26ms/step - loss: 0.1058 - accuracy: 0.9667 - val_loss: 0.0742 - val_accuracy: 1.0000
# Epoch 47/50
# 4/4 [==============================] - 0s 22ms/step - loss: 0.1016 - accuracy: 0.9750 - val_loss: 0.0733 - val_accuracy: 1.0000
# Epoch 48/50
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0998 - accuracy: 0.9667 - val_loss: 0.0723 - val_accuracy: 1.0000
# Epoch 49/50
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0974 - accuracy: 0.9667 - val_loss: 0.0702 - val_accuracy: 1.0000
# Epoch 50/50
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0942 - accuracy: 0.9667 - val_loss: 0.0670 - val_accuracy: 1.0000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0670 - accuracy: 1.0000
# Test Accuracy: 1.0
